# %% [markdown]
# ## Question1

# %%
# Ask the user for number of days
days = int (input("How many days?"))
#calculate the number of seconds and display the result
seconds = days*24*60*60

print(f"Seconds in those days are : {seconds}")
# Out:
# How many days? 3
# Seconds in those days are : 259200

# %% [markdown]
# ## Question 2

# %%
# Q2: Calculate the volume of a sphere given its radius
 ## for accuracy we have to import the math library
import math 
#Ask the user to input radius
radius = float(input("Enter the radius of the sphere: ")) 
#Calculate the volume of the sphere
volume = (4 / 3) * math.pi * radius ** 3  
#Output result
print(f"The volume of a sphere with radius {radius} is {volume:.2f}")
# Out:
# Enter the radius of the sphere:  2
# The volume of a sphere with radius 2.0 is 33.51

# %% [markdown]
# ## Question 3

# %%
#calculating area of square is side squared
def calc_area(side):
     return side * side 
#calculating perimeter of a square is side x4
def calc_perimeter(side):
    return 4 * side
#Ask user for the length of a side
side = float(input("What is the length of one side : "))
#output the results
print("Area of the square is : ", calc_area(side))
print("Perimeter of the square is : ", calc_perimeter(side))
# Out:
# What is the length of one side :  5
# Area of the square is :  25.0
# Perimeter of the square is :  20.0

# %% [markdown]
# ## Question 4

# %%
def check_case(char):
    if char.isupper():
        print("The character is uppercase")
    elif char.islower():
        print("The character is lowercase")
    else:
        print("Input invalid")
        #Ask the user to input character
char= input("Enter character: ")
check_case(char)
# Out:
# Enter character:  R
# The character is uppercase

# %% [markdown]
# ## Question 5

# %%
x=0
y=20
while True:
    y=y-4
    x=x+2/y
    if y<6:
        break
        print(X)

# %% [markdown]
# ## Question 6

# %%
#An empty list to store values
values = []
#Intitalize the total
total=0
#loop 5 times in order to get input from user
for i in range(5):
    value = float(input("Enter a value"))
    #input value into the list
    values.append(value)
    total= total + value
    #calculate average
    average = total/5
    print("Average",average)
# Out:
# Enter a value 2
# Average 0.4
# Enter a value 2
# Average 0.8
# Enter a value 2
# Average 1.2
# Enter a value 2
# Average 1.6
# Enter a value 2
# Average 2.0

# %% [markdown]
# ## Question7

# %% [markdown]
# ![image.png](attachment:b7f3711b-a96a-44a2-9106-d3aa0ecf6816.png)
